# %%
import pandas as pd
import numpy as np
import sklearn as sk
import os
#if you need to open in Spyder (file path will need to be more spelled out for read and .to_csv files)
#os.chdir('/Users/goldbellconsulting-ddb/Desktop/Dev')

# %%
#Reading in CSV files
#car_data_clean = pd.read_csv('car_data_clean.csv')
#mc_11_11_18 = pd.read_csv('mc_feed_20181111.csv')
#mc_11_12_18 = pd.read_csv('mc_feed_20181112.csv')
#mc_11_13_18 = pd.read_csv('mc_feed.csv')
#county_demo = pd.read_csv('county_demos_cleaned.csv')
#zip_county = pd.read_csv('zip_code_database_cleaned.csv')
#age = pd.read_csv('year_age.csv')
#region = pd.read_csv('regions_states.csv')

# %%
region = pd.read_csv('regions_states.csv')

# %%
region.isnull().sum()
# Out:
# States Short    0
# States          0
# Regions         0
# dtype: int64

# %%
region.to_csv('region_c.csv', index=False, header=True)

# %%
car_data_clean = pd.read_csv('car_data_clean.csv')
# Out:
# /Users/goldbellconsulting-ddb/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Checking intitial car dataset
car_data_clean.isnull().sum()
car_data_clean = car_data_clean.dropna()
car_data_clean.to_csv('car_data_clean_c.csv', index=False, header=True)

# %%
mc_11_11_18 = pd.read_csv('mc_feed_20181111.csv')

# %%
mc_11_11_18.isnull().sum()
mc_11_11_18 = mc_11_11_18.dropna()
mc_11_11_18.to_csv('mc_11_11_18_c.csv', index=False, header=True)

# %%
mc_11_12_18 = pd.read_csv('mc_feed_20181112.csv')
# Out:
# /Users/goldbellconsulting-ddb/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mc_11_12_18.isnull().sum()
mc_11_12_18 = mc_11_12_18.dropna()
mc_11_12_18.isnull().sum()
mc_11_12_18.to_csv('mc_11_12_18_c.csv', index=False, header=True)

# %%
mc_11_13_18 = pd.read_csv('mc_feed.csv')
# Out:
# /Users/goldbellconsulting-ddb/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mc_11_13_18.isnull().sum()
mc_11_13_18 = mc_11_13_18.dropna()
mc_11_13_18.to_csv('mc_11_13_18_c.csv', index=False, header=True)

# %%
county_demo = pd.read_csv('county_demos_cleaned.csv')

# %%
county_demo.isnull().sum()
county_demo = county_demo.dropna()
county_demo.to_csv('county_demo_c.csv', index=False, header=True)

# %%
zip_county = pd.read_csv('zip_code_database_cleaned.csv')

# %%
zip_county.isnull().sum()
zip_county = zip_county.dropna()
zip_county.to_csv('zip_county_c.csv', index=False, header=True)

# %%
age = pd.read_csv('year_age.csv')

# %%
age.isnull().sum()
age = age.dropna()
age.to_csv('age_c.csv', index=False, header=True)

# %%
mc_11_11_18_c = pd.read_csv('mc_11_11_18_c.csv')
mc_11_12_18_c = pd.read_csv('mc_11_12_18_c.csv')
mc_11_13_18_c = pd.read_csv('mc_11_13_18_c.csv')

#Spyder ver.
"""mc_11_11_18_c = pd.read_csv('KBB/Storage/Joins/mc_11_11_18_c.csv')
mc_11_12_18_c = pd.read_csv('KBB/Storage/Joins/mc_11_12_18_c.csv')
mc_11_13_18_c = pd.read_csv('KBB/Storage/Joins/mc_11_13_18_c.csv')"""
# Out:
# "mc_11_11_18_c = pd.read_csv('KBB/Storage/Joins/mc_11_11_18_c.csv')\nmc_11_12_18_c = pd.read_csv('KBB/Storage/Joins/mc_11_12_18_c.csv')\nmc_11_13_18_c = pd.read_csv('KBB/Storage/Joins/mc_11_13_18_c.csv')"

# %%
frames = [mc_11_11_18_c, mc_11_12_18_c, mc_11_13_18_c]
df_car_11_12_13 = pd.concat(frames, axis=0, join='outer', join_axes=None, ignore_index=False,
          keys=None, levels=None, names=None, verify_integrity=False,
          copy=True)
df_car_11_12_13.describe()
# Out:
#               price         miles          year   engine_size         doors  \
# count  1.416965e+06  1.416965e+06  1.416965e+06  1.416965e+06  1.416965e+06
# mean   2.671979e+04  3.316323e+04  2.015547e+03  2.956629e+00  3.876105e+00
# std    1.334779e+04  1.657995e+04  1.095257e+00  1.149583e+00  4.829361e-01
# min    3.210000e+02  0.000000e+00  1.994000e+03  1.000000e+00  2.000000e+00
# 25%    1.799900e+04  2.235300e+04  2.015000e+03  2.000000e+00  4.000000e+00
# 50%    2.399900e+04  3.189700e+04  2.016000e+03  2.500000e+00  4.000000e+00
# 75%    3.190300e+04  4.197700e+04  2.016000e+03  3.500000e+00  4.000000e+00
# max    9.999950e+05  6.118540e+05  2.019000e+03  7.300000e+00  5.000000e+00
#
#           cylinders  is_certified           dom       dom_180          msrp  \
# count  1.416965e+06     1416965.0  1.416965e+06  1.416965e+06  1.416965e+06
# mean   5.292503e+00           1.0  8.255489e+01  5.438537e+01  2.744025e+04
# ...

# %%
df_car_11_12_13.drop_duplicates(subset='vin', keep='first', inplace=False)
df_car_11_12_13.to_csv('car_11_12_13_c.csv', index=False, header=True)
#df_car_11_12_13 = pd.merge(df_car_11_11, mc_11_12_18, how='inner', left_on=['make_ss','model_ss'], right_on=['make','model'])

# %%
car_data_clean_c = pd.read_csv('car_data_clean_c.csv')
car_data_clean_c = car_data_clean.drop_duplicates(subset='vin_ss', keep='first', inplace=False)
car_data_clean_c.to_csv('car_data_clean_c.csv', index=False, header=True)
car_data_clean_c.head()
# Out:
# /Users/goldbellconsulting-ddb/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                      id             vin_ss  price_fs  \
# 0  00000433-1e18-46f5-befa-cb338ff4c44c  4T1BF1FK8CU553915     12997
# 1  00000847-d723-47ed-9dd6-e1d70088e35a  1C4RJEJT9EC221337     25942
# 2  00000d32-faef-4643-b0e1-b5d91ef47c6a  1HGCP3F85BA018516     10488
# 3  00000ff5-58ae-4ce0-9b41-651d9e85b478  1FTEW1CP8GFB91564     29997
# 4  0000120b-8653-495d-9c6e-b1d80996bed7  1FMEU17L63LA06903      4990
#
#    miles_fs stock_no_ss  year_is make_ss        model_ss      trim_ss  \
# 0     68475     UCJ2478     2012  Toyota           Camry            L
# 1     70897      P32069     2014    Jeep  Grand Cherokee       Summit
# 2     91599     H42760A     2011   Honda          Accord     EX-L V-6
# ...

# %%
car_11_12_13_c = pd.read_csv('car_11_12_13_c.csv')
car_11_12_13_c.isnull().sum()
# Out:
# id                0
# vin               0
# price             0
# miles             0
# year              0
# make              0
# model             0
# trim              0
# vehicle_type      0
# body_type         0
# drivetrain        0
# fuel_type         0
# engine            0
# engine_size       0
# transmission      0
# doors             0
# cylinders         0
# interior_color    0
# exterior_color    0
# scraped_at        0
# status_date       0
# zip               0
# is_certified      0
# dom               0
# dom_180           0
# msrp              0
# dom_active        0
# dtype: int64

# %%
car_data_clean_c = pd.read_csv('car_data_clean_c.csv')
car_data_clean_c.isnull().sum()
# Out:
# /Users/goldbellconsulting-ddb/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# id                   0
# vin_ss               0
# price_fs             0
# miles_fs             0
# stock_no_ss          0
# year_is              0
# make_ss              0
# model_ss             0
# trim_ss              0
# vehicle_type_ss      0
# body_type_ss         0
# drivetrain_ss        0
# engine_ss            0
# engine_size_ss       0
# transmission_ss      0
# doors_is             0
# cylinders_is         0
# interior_color_ss    0
# exterior_color_ss    0
# zip_is               0
# dom_is               0
# dom_180_is           0
# msrp_fs              0
# dom_active_is        0
# is_certified_is      0
# fuel_type_ss         0
# scraped_at_dts       0
# status_date_dts      0
# ...

# %%
car_data_clean_c = car_data_clean_c.drop(columns=['status_date_dts', 'city_ss', 'state_ss', 'stock_no_ss'])
car_11_12_13_c = car_11_12_13_c.drop(columns='status_date')

# %%
mc_car_sample_days_all.describe()
# Out:
#           cylinders  cylinders_is           dom       dom_180    dom_180_is  \
# count  1.416965e+06  1.082204e+06  1.416965e+06  1.416965e+06  1.082204e+06
# mean   5.292503e+00  5.516866e+00  8.255489e+01  5.438537e+01  7.664258e+01
# std    3.479999e+00  1.558059e+00  1.057634e+02  7.970219e+01  1.379926e+02
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.000000e+00  4.000000e+00  2.600000e+01  1.700000e+01  1.700000e+01
# 50%    4.000000e+00  6.000000e+00  5.300000e+01  3.600000e+01  3.700000e+01
# 75%    6.000000e+00  6.000000e+00  9.900000e+01  6.400000e+01  8.500000e+01
# max    9.600000e+01  1.500000e+01  2.156000e+03  2.156000e+03  2.106000e+03
#
#          dom_active  dom_active_is        dom_is         doors      doors_is  \
# count  1.416965e+06   1.082204e+06  1.082204e+06  1.416965e+06  1.082204e+06
# mean   4.808306e+01   6.509437e+01  1.087443e+02  3.876105e+00  3.832200e+00
# ...

# %%
car_data_clean_c.info()
car_11_12_13_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1082204 entries, 0 to 1082203
# Data columns (total 26 columns):
# id                   1082204 non-null object
# vin_ss               1082204 non-null object
# price_fs             1082204 non-null int64
# miles_fs             1082204 non-null int64
# year_is              1082204 non-null int64
# make_ss              1082204 non-null object
# model_ss             1082204 non-null object
# trim_ss              1082204 non-null object
# vehicle_type_ss      1082204 non-null object
# body_type_ss         1082204 non-null object
# drivetrain_ss        1082204 non-null object
# engine_ss            1082204 non-null object
# engine_size_ss       1082204 non-null float64
# transmission_ss      1082204 non-null object
# doors_is             1082204 non-null int64
# cylinders_is         1082204 non-null int64
# interior_color_ss    1082204 non-null object
# exterior_color_ss    1082204 non-null object
# ...

# %%
car_data_clean_c = car_data_clean_c.rename(index=str, columns={"vin_ss": "vin", "price_fs": "price", "miles_fs": "miles", "year_is": "year", "make_ss": "make", "model_ss": "model", "trim_ss": "trim", "vehicle_type_ss": "vehicle_type", "body_type_ss": "body_type", "drivetrain_ss": "drivetrain", "engine_ss":"engine", "engine_size_ss": "engine_size", "transmission_ss": "transmission", "doors_is": "doors", "cylinders_is": "cylinders", "interior_color_ss": "interior_color", "exterior_color_ss": "exterior_color", "zip_is": "zip", "dom_is": "dom", "dom_180_is": "dom_180", "msrp_fs": "msrp", "dom_active_is": "dom_active", "is_certified_is": "is_certified", "fuel_type_ss": "fuel_type", "scraped_at_dts": "scraped_at"})

# %%
frames = [car_data_clean_c, car_11_12_13_c]

mc_car_sample_days_all = pd.concat(frames, axis=0, join='outer', join_axes=None, ignore_index=False,
          keys=None, levels=None, names=None, verify_integrity=False,
          copy=True)
# Out:
# /Users/goldbellconsulting-ddb/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False

# %%
mc_car_sample_days_all.isnull().sum()
# Out:
# body_type         0
# cylinders         0
# dom               0
# dom_180           0
# dom_active        0
# doors             0
# drivetrain        0
# engine            0
# engine_size       0
# exterior_color    0
# fuel_type         0
# id                0
# interior_color    0
# is_certified      0
# make              0
# miles             0
# model             0
# msrp              0
# price             0
# scraped_at        0
# transmission      0
# trim              0
# vehicle_type      0
# vin               0
# year              0
# zip               0
# dtype: int64

# %%
mc_car_sample_days_all = mc_car_sample_days_all.drop_duplicates(subset='vin', keep='first', inplace=False)

# %%
mc_car_sample_days_all.describe()
# Out:
#           cylinders           dom       dom_180    dom_active         doors  \
# count  1.193917e+06  1.193917e+06  1.193917e+06  1.193917e+06  1.193917e+06
# mean   5.509911e+00  1.040657e+02  7.249023e+01  6.169621e+01  3.837588e+00
# std    2.150813e+00  1.618226e+02  1.336564e+02  1.139262e+02  5.463149e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  2.000000e+00
# 25%    4.000000e+00  2.400000e+01  1.600000e+01  1.200000e+01  4.000000e+00
# 50%    6.000000e+00  5.400000e+01  3.400000e+01  3.000000e+01  4.000000e+00
# 75%    6.000000e+00  1.220000e+02  7.800000e+01  6.600000e+01  4.000000e+00
# max    9.600000e+01  2.106000e+03  2.106000e+03  2.106000e+03  5.000000e+00
#
#         engine_size  is_certified         miles          msrp         price  \
# count  1.193917e+06  1.193917e+06  1.193917e+06  1.193917e+06  1.193917e+06
# mean   3.278424e+00  2.036942e-01  5.981066e+04  2.184840e+04  2.132529e+04
# ...

# %%
mc_car_sample_days_all.to_csv('mc_car_sample_days_all.csv', index=False, header=True)

# %%
county_demo = pd.read_csv('county_demo_c.csv')
zip_county = pd.read_csv('zip_county_c.csv')
age = pd.read_csv('age_c.csv')
region = pd.read_csv('region_c.csv')

# %%
county_region = pd.merge(county_demo, region, how='inner', left_on='State short', right_on='States Short')

# %%
county_region_zip = pd.merge(county_region, zip_county, how='inner', left_on=['County', 'State short'], right_on=['county', 'state'])

county_region_zip['zip'] = county_region_zip['zip'].astype(str)

# %%
county_region_zip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40819 entries, 0 to 40818
# Data columns (total 23 columns):
# Rank                             40819 non-null int64
# County                           40819 non-null object
# State short                      40819 non-null object
# Per Capita income                40819 non-null object
# Median Household income          40819 non-null object
# Median Family income             40819 non-null object
# Population                       40819 non-null int64
# Number of households             40819 non-null int64
# State full                       40819 non-null object
# States Short                     40819 non-null object
# States                           40819 non-null object
# Regions                          40819 non-null object
# zip                              40819 non-null object
# type                             40819 non-null object
# decommissioned                   40819 non-null int64
# ...

# %%
county_region_zip.to_csv('county_region_zip_c.csv', index=False, header=True)

# %%
df = pd.read_csv('mc_car_sample_days_all.csv')
df.describe()
# Out:
# /Users/goldbellconsulting-ddb/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           cylinders           dom       dom_180    dom_active         doors  \
# count  1.193917e+06  1.193917e+06  1.193917e+06  1.193917e+06  1.193917e+06
# mean   5.509911e+00  1.040657e+02  7.249023e+01  6.169621e+01  3.837588e+00
# std    2.150813e+00  1.618226e+02  1.336564e+02  1.139262e+02  5.463149e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  2.000000e+00
# 25%    4.000000e+00  2.400000e+01  1.600000e+01  1.200000e+01  4.000000e+00
# 50%    6.000000e+00  5.400000e+01  3.400000e+01  3.000000e+01  4.000000e+00
# 75%    6.000000e+00  1.220000e+02  7.800000e+01  6.600000e+01  4.000000e+00
# max    9.600000e+01  2.106000e+03  2.106000e+03  2.106000e+03  5.000000e+00
#
# ...

# %%
df_no_age = pd.merge(df, county_region_zip, how='inner', left_on='zip', right_on='zip')

df_no_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 994679 entries, 0 to 994678
# Data columns (total 48 columns):
# body_type                        994679 non-null object
# cylinders                        994679 non-null float64
# dom                              994679 non-null int64
# dom_180                          994679 non-null int64
# dom_active                       994679 non-null int64
# doors                            994679 non-null float64
# drivetrain                       994679 non-null object
# engine                           994679 non-null object
# engine_size                      994679 non-null float64
# exterior_color                   994679 non-null object
# fuel_type                        994679 non-null object
# id                               994679 non-null object
# interior_color                   994679 non-null object
# is_certified                     994679 non-null float64
# make                             994679 non-null object
# ...

# %%
df_age = pd.merge(df_no_age, age, how='inner', left_on='year', right_on='YEAR')

# %%
df_age = df_age.drop_duplicates(subset='vin', keep='first', inplace=False)

# %%
df_age.to_csv('mc_car_sample_days_all_complete.csv', index=False, header=True)

# %%
df_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 994593 entries, 0 to 994592
# Data columns (total 50 columns):
# body_type                        994593 non-null object
# cylinders                        994593 non-null float64
# dom                              994593 non-null int64
# dom_180                          994593 non-null int64
# dom_active                       994593 non-null int64
# doors                            994593 non-null float64
# drivetrain                       994593 non-null object
# engine                           994593 non-null object
# engine_size                      994593 non-null float64
# exterior_color                   994593 non-null object
# fuel_type                        994593 non-null object
# id                               994593 non-null object
# interior_color                   994593 non-null object
# is_certified                     994593 non-null float64
# make                             994593 non-null object
# ...

# %%
df_all = pd.read_csv('mc_car_sample_days_all_complete.csv')

# %%
df_all.drop(["YEAR", "county", "States", "state", "State short", "County", "fuel_type"], axis=1, inplace=True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 994593 entries, 0 to 994592
# Data columns (total 43 columns):
# body_type                        994593 non-null object
# cylinders                        994593 non-null float64
# dom                              994593 non-null int64
# dom_180                          994593 non-null int64
# dom_active                       994593 non-null int64
# doors                            994593 non-null float64
# drivetrain                       994593 non-null object
# engine                           994593 non-null object
# engine_size                      994593 non-null float64
# exterior_color                   994593 non-null object
# id                               994593 non-null object
# interior_color                   994593 non-null object
# is_certified                     994593 non-null float64
# make                             994593 non-null object
# miles                            994593 non-null float64
# ...

# %%
df_all.to_csv('mc_car_sample_days_all_complete.csv', index=False, header=True)

# %%
#Remove 
df = df[df.state_ss != 'WS']

# %%
#Finding and removing low quantity/ low value Makes 
#df.make_ss.unique()
df_all['make'].value_counts()
#df.make_ss.count()
# Out:
# Ford             135613
# Chevrolet        130219
# Toyota            82313
# Nissan            69216
# Jeep              55112
# Honda             50424
# GMC               40573
# Hyundai           40450
# Dodge             35712
# BMW               34196
# Mercedes-Benz     32250
# Lexus             29571
# Ram               27580
# Kia               26763
# Volkswagen        25360
# Subaru            20673
# Cadillac          17531
# Buick             16563
# Mazda             16158
# Audi              14168
# Acura             13699
# Chrysler          13611
# INFINITI          11967
# Lincoln           10039
# Land Rover         6854
# Porsche            5958
# Volvo              5569
# MINI               4751
# Mitsubishi         3782
# Scion              2839
# Pontiac            2664
# Jaguar             2291
# Mercury            1430
# Saturn             1412
# HUMMER             1382
# FIAT               1241
# Maserati           1183
# Bentley             661
# ...

# %%
#Removing Makes with fewer than 6,000 entries - (optional)
df = df_all[df_all.make != 'McLaren'] # 'Scion', 'Jaguar', 'FIAT', 'smart','Aston Martin', 'Mitsubishi', 'Pontiac', 'Saab','Maserati', 'HUMMER', 'Lamborghini', 'Ferrari', 'McLaren', 'Bentley', 'Oldsmobile', 'Rolls-Royce', 'Mercury', 'Saturn', 'Suzuki', 'Plymouth', 'Isuzu', 'Lotus', 'Alfa Romeo', 'Geo', 'Fisker', 'AM General', 'Daewoo', 'Panoz', 'Maybach')

# %%
df['make'].value_counts()
# Out:
# Ford             135613
# Chevrolet        130219
# Toyota            82313
# Nissan            69216
# Jeep              55112
# Honda             50424
# GMC               40573
# Hyundai           40450
# Dodge             35712
# BMW               34196
# Mercedes-Benz     32250
# Lexus             29571
# Ram               27580
# Kia               26763
# Volkswagen        25360
# Subaru            20673
# Cadillac          17531
# Buick             16563
# Mazda             16158
# Audi              14168
# Acura             13699
# Chrysler          13611
# INFINITI          11967
# Lincoln           10039
# Land Rover         6854
# Porsche            5958
# Volvo              5569
# MINI               4751
# Mitsubishi         3782
# Scion              2839
# Pontiac            2664
# Jaguar             2291
# Mercury            1430
# Saturn             1412
# HUMMER             1382
# FIAT               1241
# Maserati           1183
# Bentley             661
# ...

# %%
df.year_is.unique()

# %%
#Removing years (1990 - 1999)
df = df[df.year_is != 1999] #1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999

# %%
#Removing Zeros from the IRS Estimated POP Column
df = df[df.irs_estimated_population_2015 != 0]

# %%
#saving Final Version
df.to_csv('car_data_clean_complete_v4.csv', index=False, header=True)
